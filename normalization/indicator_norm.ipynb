# %%
import sys
import os

# get project root for python script import
project_root = os.path.abspath("..")
sys.path.append(project_root)

from scripts.normalization import normalize_indicator

# %%
# adult living alone data
adult_living_alone = normalize_indicator("adult_living_alone_data.csv", "% Householder 65 years and over living alone, 2024")
display(adult_living_alone)
# Out:
#            GEOID           Name of geographic unit  Short Label  \
# 0    13067030104  Census Tract 301.04, Cobb County       301.04
# 1    13067030107  Census Tract 301.07, Cobb County       301.07
# 2    13067030108  Census Tract 301.08, Cobb County       301.08
# 3    13067030109  Census Tract 301.09, Cobb County       301.09
# 4    13067030110  Census Tract 301.10, Cobb County       301.10
# ..           ...                               ...          ...
# 181  13067031514  Census Tract 315.14, Cobb County       315.14
# 182  13067031515  Census Tract 315.15, Cobb County       315.15
# 183  13067031516  Census Tract 315.16, Cobb County       315.16
# 184  13067031517  Census Tract 315.17, Cobb County       315.17
# 185  13067031518  Census Tract 315.18, Cobb County       315.18
#
#     Summary level of geographic unit  Geography Vintage  \
# 0                              Tract               2020
# 1                              Tract               2020
# ...
