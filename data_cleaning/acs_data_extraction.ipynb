# %% [markdown]
# ### Data Extraction for ACS Data
# Uses the clean_acs_data function for each ACS dataset

# %%
import sys
import os

# get project root for python script import
project_root = os.path.abspath("..")
sys.path.append(project_root)

from scripts.acs_cleaning import clean_acs_data

# %%
import pandas as pd

# %%
# households with no vehicle data
no_vehicle_data = clean_acs_data("1_ACS 2024 Housing Vehicles_8466374152199112599.csv", "% Occupied housing units, no vehicles available, 2024", "no_vehicle_data.csv")
display(no_vehicle_data)
# Out:
#            GEOID  % Occupied housing units, no vehicles available, 2024
# 528  13067030104                                               15.1
# 529  13067030107                                                1.3
# 530  13067030108                                                0.0
# 531  13067030109                                                1.3
# 532  13067030110                                                7.9
# ..           ...                                                ...
# 709  13067031514                                                0.6
# 710  13067031515                                                2.4
# 711  13067031516                                                2.2
# 712  13067031517                                                4.7
# 713  13067031518                                                1.6
#
# [186 rows x 2 columns]

# %%
# travel to work data
travel_to_work_data = clean_acs_data("2_ACS 2024 Econ Commuting_8162086740063256068.csv", ["Mean travel time to work (minutes), 2024",
                                                                                           "Mean travel time to work (minutes), 2024",
                                                                                           "# Workers 16 years and over, 2024",
                                                                                           "# Car, truck, or van - carpooled to work, 2024",
                                                                                           "% Car, truck, or van - carpooled to work, 2024",
                                                                                           "# Public transportation to work, 2024",
                                                                                           "% Public transportation to work, 2024",
                                                                                           "# Walked to work, 2024",
                                                                                           "% Walked to work, 2024",],
                                                                                           "travel_to_work_data.csv")
display(travel_to_work_data)
# Out:
#            GEOID  Mean travel time to work (minutes), 2024  \
# 528  13067030104                                      31.8
# 529  13067030107                                      30.2
# 530  13067030108                                      28.4
# 531  13067030109                                      36.6
# 532  13067030110                                      31.0
# ..           ...                                       ...
# 709  13067031514                                      33.2
# 710  13067031515                                      33.3
# 711  13067031516                                      34.2
# 712  13067031517                                      34.0
# 713  13067031518                                      34.5
#
#      # Workers 16 years and over, 2024  \
# 528                               1855
# 529                               2651
# 530                               2090
# 531                               2073
# 532                               2517
# ...

# %%
# educational attainment data
educational_attainment_data = clean_acs_data("4_ACS 2024 Social EdAttainment_-6456078396238709508.csv", "% Population 25 years and over, bachelor's degree, 2024", "edu_attainment_data.csv")
display(educational_attainment_data)
# Out:
#            GEOID  % Population 25 years and over, bachelor's degree, 2024
# 528  13067030104                                               13.7
# 529  13067030107                                               25.7
# 530  13067030108                                               34.0
# 531  13067030109                                               34.1
# 532  13067030110                                               29.3
# ..           ...                                                ...
# 709  13067031514                                               24.6
# 710  13067031515                                               31.9
# 711  13067031516                                               42.5
# 712  13067031517                                               25.6
# 713  13067031518                                               26.1
#
# [186 rows x 2 columns]

# %%
# unemployment data
unemployment_rate_data = clean_acs_data("6_ACS 2024 Econ Unemployment_2563786966605419871.csv", "% Unemployment Rate, 2024", "unemployment_rate_data.csv")
display(unemployment_rate_data)
# Out:
#            GEOID  % Unemployment Rate, 2024
# 528  13067030104                        4.8
# 529  13067030107                        3.2
# 530  13067030108                        1.7
# 531  13067030109                        2.9
# 532  13067030110                        5.3
# ..           ...                        ...
# 709  13067031514                        9.6
# 710  13067031515                        4.2
# 711  13067031516                        1.5
# 712  13067031517                        4.8
# 713  13067031518                        2.3
#
# [186 rows x 2 columns]

# %%
# opportunity youth data
opportunity_youth_data = clean_acs_data("7_ACS 2024 Social OppYouth_-8422107928256140074.csv", "% Disconnected youth: ages 16-19 not in school or in labor force, 2024", "opportunity_youth_data.csv")
display(opportunity_youth_data)
# Out:
#            GEOID  \
# 528  13067030104
# 529  13067030107
# 530  13067030108
# 531  13067030109
# 532  13067030110
# ..           ...
# 709  13067031514
# 710  13067031515
# 711  13067031516
# 712  13067031517
# 713  13067031518
#
#      % Disconnected youth: ages 16-19 not in school or in labor force, 2024
# 528                                                0.0
# 529                                                0.0
# 530                                                1.9
# 531                                                0.0
# 532                                                5.6
# ..                                                 ...
# 709                                               23.3
# 710                                                0.0
# 711                                                0.0
# 712                                                0.0
# 713                                                3.7
#
# [186 rows x 2 columns]

# %%
# rent burden data
rent_burden_data = clean_acs_data("8_ACS 2024 Housing Affordability_8949469524208423615.csv", "% Gross rent 30.0 percent of income or greater, 2024", "rent_burden_data.csv")
display(rent_burden_data)
# Out:
#            GEOID  % Gross rent 30.0 percent of income or greater, 2024
# 528  13067030104                                               54.0
# 529  13067030107                                               61.9
# 530  13067030108                                               62.4
# 531  13067030109                                               74.3
# 532  13067030110                                               52.9
# ..           ...                                                ...
# 709  13067031514                                               53.3
# 710  13067031515                                               21.3
# 711  13067031516                                               80.0
# 712  13067031517                                               42.3
# 713  13067031518                                               52.9
#
# [186 rows x 2 columns]

# %%
# renter occupied data
renter_occupied_data = clean_acs_data("9_ACS 2024 Housing Tenure_-4454289415699796728.csv", "% Renter-occupied housing units, 2024", "renter_occupied_data.csv")
display(renter_occupied_data)
# Out:
#            GEOID  % Renter-occupied housing units, 2024
# 528  13067030104                                   48.2
# 529  13067030107                                   17.8
# 530  13067030108                                   11.7
# 531  13067030109                                   32.4
# 532  13067030110                                   29.0
# ..           ...                                    ...
# 709  13067031514                                   10.7
# 710  13067031515                                    5.3
# 711  13067031516                                   15.4
# 712  13067031517                                   25.5
# 713  13067031518                                   14.6
#
# [186 rows x 2 columns]

# %%
# median home value data
median_home_value_data = clean_acs_data("10_ACS 2024 Housing HValue_-2583162591557982240.csv", "Median value of owner-occupied unit (dollars), 2024", "median_home_value_data.csv")
display(median_home_value_data)
# Out:
#            GEOID  Median value of owner-occupied unit (dollars), 2024
# 528  13067030104                                           330400.0
# 529  13067030107                                           360600.0
# 530  13067030108                                           530000.0
# 531  13067030109                                           382600.0
# 532  13067030110                                           365300.0
# ..           ...                                                ...
# 709  13067031514                                           322200.0
# 710  13067031515                                           414200.0
# 711  13067031516                                           415400.0
# 712  13067031517                                           398400.0
# 713  13067031518                                           329600.0
#
# [186 rows x 2 columns]

# %%
# no health insurance data
no_health_ins_data = clean_acs_data("11_ACS 2024 Econ HealthIns_-7160900534032778288.csv", "% Civilian non-institutionalized population, no health insurance, 2024", "no_health_ins_data.csv")
display(no_health_ins_data)
# Out:
#            GEOID  \
# 528  13067030104
# 529  13067030107
# 530  13067030108
# 531  13067030109
# 532  13067030110
# ..           ...
# 709  13067031514
# 710  13067031515
# 711  13067031516
# 712  13067031517
# 713  13067031518
#
#      % Civilian non-institutionalized population, no health insurance, 2024
# 528                                               17.8
# 529                                                9.2
# 530                                               18.0
# 531                                                8.6
# 532                                               15.3
# ..                                                 ...
# 709                                               15.7
# 710                                                9.5
# 711                                                8.6
# 712                                               17.1
# 713                                               17.0
#
# [186 rows x 2 columns]

# %%
# preschool enrollment data
preschool_enroll_data = clean_acs_data("12_ACS 2024 Social Enrollment_4807511731336504071.csv", "% Enrolled in nursery school, preschool, 2024", "preschool_enroll_data.csv")
display(preschool_enroll_data)
# Out:
#            GEOID  % Enrolled in nursery school, preschool, 2024
# 528  13067030104                                            7.3
# 529  13067030107                                            2.2
# 530  13067030108                                            4.0
# 531  13067030109                                            0.0
# 532  13067030110                                           13.1
# ..           ...                                            ...
# 709  13067031514                                            5.0
# 710  13067031515                                           10.0
# 711  13067031516                                            4.9
# 712  13067031517                                            2.3
# 713  13067031518                                            0.0
#
# [186 rows x 2 columns]

# %%
# adult living alone data
adult_living_alone_data = clean_acs_data("13_ACS 2024 Social HouseholdComp_-815603963663474813.csv", "% Householder 65 years and over living alone, 2024", "adult_living_alone_data.csv")
display(adult_living_alone_data)
# Out:
#            GEOID  % Householder 65 years and over living alone, 2024
# 528  13067030104                                               26.6
# 529  13067030107                                               14.3
# 530  13067030108                                                9.4
# 531  13067030109                                               12.1
# 532  13067030110                                               15.5
# ..           ...                                                ...
# 709  13067031514                                                7.2
# 710  13067031515                                                6.2
# 711  13067031516                                                2.4
# 712  13067031517                                               13.9
# 713  13067031518                                                9.6
#
# [186 rows x 2 columns]

# %%
# single parent families data
single_parent_fam_data = clean_acs_data("14_ACS 2024 Social FamilyType_1334278305550881535.csv", "% Single parent families with own children of the householder, 2024", "single_parent_fam_data.csv")
display(single_parent_fam_data)
# Out:
#            GEOID  \
# 528  13067030104
# 529  13067030107
# 530  13067030108
# 531  13067030109
# 532  13067030110
# ..           ...
# 709  13067031514
# 710  13067031515
# 711  13067031516
# 712  13067031517
# 713  13067031518
#
#      % Single parent families with own children of the householder, 2024
# 528                                                7.7
# 529                                                7.7
# 530                                                6.1
# 531                                                7.2
# 532                                               13.8
# ..                                                 ...
# 709                                                5.7
# 710                                                1.3
# 711                                               12.8
# 712                                               20.7
# 713                                                9.3
#
# [186 rows x 2 columns]

# %%
# children raised by grandparents data
child_grandparent_data = clean_acs_data("15_ACS 2024 Social Grandparents_-2320451481639583259.csv", "% Children raised by grandparent, 2024", "child_grandparent_data.csv")
display(child_grandparent_data)
# Out:
#            GEOID  % Children raised by grandparent, 2024
# 528  13067030104                                     0.0
# 529  13067030107                                     0.0
# 530  13067030108                                     5.2
# 531  13067030109                                    22.7
# 532  13067030110                                     0.0
# ..           ...                                     ...
# 709  13067031514                                     4.6
# 710  13067031515                                     0.8
# 711  13067031516                                     4.7
# 712  13067031517                                     5.9
# 713  13067031518                                     0.5
#
# [186 rows x 2 columns]

# %%
# children under 5 data
under_5_data = clean_acs_data("16_ACS 2024 Demographic SexAge_-709996168819570625.csv", ["# Age under 5 years, 2024", "% Age under 5 years, 2024"], "under_5_data.csv")
display(under_5_data)
# Out:
#            GEOID  # Age under 5 years, 2024  % Age under 5 years, 2024
# 528  13067030104                         85                        2.3
# 529  13067030107                        156                        3.6
# 530  13067030108                        342                        6.4
# 531  13067030109                        254                        5.4
# 532  13067030110                        254                        5.8
# ..           ...                        ...                        ...
# 709  13067031514                        156                        5.2
# 710  13067031515                        211                        5.4
# 711  13067031516                         85                        2.9
# 712  13067031517                        188                        5.7
# 713  13067031518                        159                        5.3
#
# [186 rows x 3 columns]

# %%
# child poverty rate
child_poverty_data = clean_acs_data("5_ACS 2024 Econ Poverty_-6377018709685928907.csv", ["# Children for whom poverty status is determined, 2024", "% Children in families below 200 percent of the poverty line, 2024"], "child_poverty_data.csv")
display(child_poverty_data)
# Out:
#            GEOID  # Children for whom poverty status is determined, 2024  \
# 528  13067030104                                                634
# 529  13067030107                                                893
# 530  13067030108                                               1700
# 531  13067030109                                               1562
# 532  13067030110                                                943
# ..           ...                                                ...
# 709  13067031514                                                696
# 710  13067031515                                                660
# 711  13067031516                                                718
# 712  13067031517                                                680
# 713  13067031518                                                715
#
#      % Children in families below 200 percent of the poverty line, 2024
# 528                                               39.0
# ...

# %%
# household income data
# DID NOT INCLUDE % households making $100K+
# ADD IF NEEDED
household_income_data = clean_acs_data("18_ACS 2024 Econ Income_8541204371224855650.csv", "Median household income, 2024", "household_income_data.csv")
display(household_income_data)
# Out:
#            GEOID  Median household income, 2024
# 528  13067030104                        63979.0
# 529  13067030107                       105694.0
# 530  13067030108                       118232.0
# 531  13067030109                       109563.0
# 532  13067030110                       105170.0
# ..           ...                            ...
# 709  13067031514                       100882.0
# 710  13067031515                       152723.0
# 711  13067031516                       106696.0
# 712  13067031517                       101200.0
# 713  13067031518                        84014.0
#
# [186 rows x 2 columns]
